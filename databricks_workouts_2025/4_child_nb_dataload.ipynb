# %%
# %py
import requests
rqst = requests.get("https://public.tableau.com/app/sample-data/mobile_os_usage.csv")  
#desti_path = "/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"
rqsttext = rqst.text
dbutils.fs.put("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv", rqsttext, overwrite=True)
