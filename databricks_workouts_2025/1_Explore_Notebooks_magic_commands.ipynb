# %% [markdown]
# #DataEngineering _Batch36_ Workout - **Balaji**#
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
displayHTML('<span style="background-color: yellow; color: black; fopnt-weight: bold; font-style: italic">_Batch36_</span>')

# %% [markdown]
# $$
# \textcolor{green}{This is green text}
# $$

# %% [markdown]
# #embed the url
# [Click Here to Display <-](https://www.amazon.in/)

# %%
# %sql
Create volume if not exists workspace.default.usage_metrics;

# %%
# %run /Users/vplrsb@gmail.com/databricksrepo/databricks_workouts_2025/4_child_nb_dataload

# %%
# %fs ls /Volumes/workspace/default/usage_metrics/

# %%
# %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv/

# %%
# %python
df1 = spark.read.csv('/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv', header=True, inferSchema=True)
display(df1)

# %%
# %sql
drop table workspace.default.mobile_os_usage;

# %%
# %sql
CREATE TABLE IF NOT EXISTS default.mobile_os_usage (`Date` DATE,`Mobile_Operating_System` STRING,`Percent_of_Usage` DOUBLE);

# %%
# %python
df1 = spark.read.csv('/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv', header=True, inferSchema=True)
#display(df1);
#print(df1.is_cached)
df1.cache;
df2 = df1
#display(df2);
df2_clean = (
    df2
    .withColumnRenamed("Mobile Operating System", "Mobile_Operating_System")
    .withColumnRenamed("Percent of Usage", "Percent_of_Usage")
)
df2_clean.write.mode("overwrite").saveAsTable("default.mobile_os_usage")
#df2.write.saveAsTable('mobile_os_usage');

# %%
# %sql
select * from workspace.default.mobile_os_usage;

# %%
# %python
input_text = input("Please enter your name, it will convert to upper case")
input_text1 = str.upper(input_text)
print(input_text1)

# %%
# %pip install pandas

# %%
import pandas as pd
df = pd.read_csv('/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv').head(10)
display(df)

# %%
# %sh
echo "Magic commands tasks completed"
